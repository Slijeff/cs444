# %%
# you will be prompted with a window asking to grant permissions
from google.colab import drive, runtime
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# fill in the path in your Google Drive in the string below. Note: do not escape slashes or spaces
import os
datadir = "/content/assignment3"
if not os.path.exists(datadir):
  # !ln -s "/content/drive/My Drive/assignment3_part2_copy/" $datadir # TODO: Fill your Assignment 3 path
os.chdir(datadir)
# !pwd
# Out:
# /content/drive/My Drive/assignment3_part2_copy

# %%
# In a terminal, Run the `download_data.sh` script in the data folder of assignment 3 part 2
# !sh download_data.sh

# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader
from torchvision import models

from src.resnet_yolo import resnet50
from yolo_loss import YoloLoss
# from yolo_loss_other import YoloLoss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Initialization

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
if torch.cuda.is_available():
    device = torch.device("cuda:0")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(device)
# Out:
# cpu

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
# load_network_path = None
# load_network_path = 'checkpoints/best_detector.pth'
load_network_path = 'checkpoints/detector.pth'
# load_network_path = 'checkpoints/v2/detector.pth'
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net = torch.compile(net)
    if device == torch.device("cpu"):
      net.load_state_dict(torch.load(load_network_path, map_location=torch.device('cpu')))
    else:
      net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)

# net = torch.compile(net)
# Out:
# Loading saved network from checkpoints/detector.pth

# %%
learning_rate = 0.001
num_epochs = 10
batch_size = 24

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.5

weight_save_prefix = 'checkpoints/'

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = './data/VOCdevkit_2007/VOC2007/JPEGImages/'
annotation_file_train = './data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = './data/VOCdevkit_2007/VOC2007test/JPEGImages/'
annotation_file_test = './data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
# data = train_dataset[0]

# %% [markdown]
# ## Set up training tools

# %%
criterion = YoloLoss(S, B, lambda_coord, lambda_noobj, device)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = 1e-3
learning_rate /= 10.0
for epoch in range(num_epochs):
    net.train()

    # Update learning rate late in training
    # if epoch == 30 or epoch == 40:
    #     learning_rate /= 10.0

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate

    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))

    total_loss = collections.defaultdict(int)

    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()

        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.5f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)

    # evaluate the network on the test data
    # if (epoch + 1) % 5 == 0:
    #     test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
    #     print(epoch, test_aps)
    # with torch.no_grad():
    #     test_loss = 0.0
    #     net.eval()
    #     for i, data in enumerate(test_loader):
    #         data = (item.to(device) for item in data)
    #         images, target_boxes, target_cls, has_object_map = data

    #         pred = net(images)
    #         loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
    #         test_loss += loss_dict['total_loss'].item()
    #     test_loss /= len(test_loader)

    # if best_test_loss > test_loss:
    #     best_test_loss = test_loss
    #     print('Updating best test loss: %.5f' % best_test_loss)
        # torch.save(net.state_dict(),'checkpoints/best_detector.pth')

    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(), weight_save_prefix + 'detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(), weight_save_prefix + 'detector.pth')
# Out:
# Starting epoch 1 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [1/10], Iter [10/209], Loss: total=1.53133, reg=17.57254, containing_obj=13.01746, no_obj=5.05660, cls=1.10531
# Epoch [1/10], Iter [20/209], Loss: total=1.49858, reg=17.15877, containing_obj=12.53889, no_obj=5.20216, cls=1.06602
# Epoch [1/10], Iter [30/209], Loss: total=1.46481, reg=16.53017, containing_obj=12.37215, no_obj=5.29111, cls=0.96193
# Epoch [1/10], Iter [40/209], Loss: total=1.48056, reg=16.82208, containing_obj=12.58661, no_obj=5.24368, cls=0.88102
# Epoch [1/10], Iter [50/209], Loss: total=1.48484, reg=16.84351, containing_obj=12.78147, no_obj=5.20043, cls=0.81083
# Epoch [1/10], Iter [60/209], Loss: total=1.51814, reg=17.33157, containing_obj=13.02252, no_obj=5.12680, cls=0.95457
# Epoch [1/10], Iter [70/209], Loss: total=1.50301, reg=17.11471, containing_obj=12.82998, no_obj=5.14795, cls=0.97971
# Epoch [1/10], Iter [80/209], Loss: total=1.49151, reg=16.99627, containing_obj=12.68335, no_obj=5.16403, cls=0.95261
# Epoch [1/10], Iter [90/209], Loss: total=1.49574, reg=17.13239, containing_obj=12.73562, no_obj=5.12551, cls=0.90413
# Epoch [1/10], Iter [100/209], Loss: total=1.49246, reg=17.10987, containing_obj=12.70782, no_obj=5.12136, cls=0.87998
# Epoch [1/10], Iter [110/209], Loss: total=1.48416, reg=17.00813, containing_obj=12.59482, no_obj=5.16202, cls=0.85481
# Epoch [1/10], Iter [120/209], Loss: total=1.47595, reg=16.85297, containing_obj=12.56864, no_obj=5.16361, cls=0.83753
# Epoch [1/10], Iter [130/209], Loss: total=1.47667, reg=16.89750, containing_obj=12.53893, no_obj=5.16281, cls=0.84076
# Epoch [1/10], Iter [140/209], Loss: total=1.47854, reg=16.91897, containing_obj=12.55538, no_obj=5.16542, cls=0.84530
# Epoch [1/10], Iter [150/209], Loss: total=1.48162, reg=16.94719, containing_obj=12.60418, no_obj=5.15729, cls=0.85030
# Epoch [1/10], Iter [160/209], Loss: total=1.48295, reg=16.97450, containing_obj=12.59484, no_obj=5.15853, cls=0.86295
# Epoch [1/10], Iter [170/209], Loss: total=1.48261, reg=16.94780, containing_obj=12.60259, no_obj=5.16523, cls=0.86695
# Epoch [1/10], Iter [180/209], Loss: total=1.48343, reg=16.97620, containing_obj=12.62575, no_obj=5.15113, cls=0.84918
# Epoch [1/10], Iter [190/209], Loss: total=1.48792, reg=17.04968, containing_obj=12.68626, no_obj=5.14090, cls=0.83335
# Epoch [1/10], Iter [200/209], Loss: total=1.48523, reg=16.98676, containing_obj=12.68988, no_obj=5.13744, cls=0.83142
#
#
# Starting epoch 2 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [2/10], Iter [10/209], Loss: total=1.60767, reg=18.63186, containing_obj=13.57869, no_obj=4.97311, cls=1.40037
# Epoch [2/10], Iter [20/209], Loss: total=1.56617, reg=18.27164, containing_obj=13.31627, no_obj=5.01121, cls=0.98885
# Epoch [2/10], Iter [30/209], Loss: total=1.60192, reg=18.37373, containing_obj=14.21628, no_obj=4.93414, cls=0.92205
# Epoch [2/10], Iter [40/209], Loss: total=1.54339, reg=17.59760, containing_obj=13.58458, no_obj=4.97461, cls=0.88458
# Epoch [2/10], Iter [50/209], Loss: total=1.56000, reg=17.87160, containing_obj=13.64090, no_obj=4.98294, cls=0.94453
# Epoch [2/10], Iter [60/209], Loss: total=1.52338, reg=17.39408, containing_obj=13.21285, no_obj=5.03135, cls=0.92290
# Epoch [2/10], Iter [70/209], Loss: total=1.50240, reg=17.15287, containing_obj=13.01512, no_obj=5.03778, cls=0.85185
# Epoch [2/10], Iter [80/209], Loss: total=1.49137, reg=17.01723, containing_obj=12.94493, no_obj=5.04228, cls=0.78848
# Epoch [2/10], Iter [90/209], Loss: total=1.49202, reg=16.92923, containing_obj=13.02988, no_obj=5.03956, cls=0.80971
# Epoch [2/10], Iter [100/209], Loss: total=1.47091, reg=16.65338, containing_obj=12.82021, no_obj=5.05497, cls=0.77320
# Epoch [2/10], Iter [110/209], Loss: total=1.47164, reg=16.67412, containing_obj=12.77402, no_obj=5.07397, cls=0.79718
# Epoch [2/10], Iter [120/209], Loss: total=1.47001, reg=16.63473, containing_obj=12.75683, no_obj=5.06171, cls=0.82702
# Epoch [2/10], Iter [130/209], Loss: total=1.46745, reg=16.62697, containing_obj=12.69949, no_obj=5.07034, cls=0.82207
# Epoch [2/10], Iter [140/209], Loss: total=1.46928, reg=16.65927, containing_obj=12.67848, no_obj=5.07564, cls=0.84921
# Epoch [2/10], Iter [150/209], Loss: total=1.46500, reg=16.60585, containing_obj=12.62629, no_obj=5.08540, cls=0.84254
# Epoch [2/10], Iter [160/209], Loss: total=1.46255, reg=16.56028, containing_obj=12.59102, no_obj=5.09933, cls=0.85045
# Epoch [2/10], Iter [170/209], Loss: total=1.46193, reg=16.53874, containing_obj=12.59552, no_obj=5.10088, cls=0.85116
# Epoch [2/10], Iter [180/209], Loss: total=1.47429, reg=16.72574, containing_obj=12.68955, no_obj=5.09312, cls=0.87453
# Epoch [2/10], Iter [190/209], Loss: total=1.47020, reg=16.70698, containing_obj=12.59534, no_obj=5.10314, cls=0.87941
# Epoch [2/10], Iter [200/209], Loss: total=1.46870, reg=16.65527, containing_obj=12.61503, no_obj=5.10894, cls=0.86965
#
#
# Starting epoch 3 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [3/10], Iter [10/209], Loss: total=1.41846, reg=15.60306, containing_obj=12.79352, no_obj=4.82132, cls=0.82522
# Epoch [3/10], Iter [20/209], Loss: total=1.38241, reg=15.34035, containing_obj=12.11239, no_obj=4.96926, cls=0.75592
# Epoch [3/10], Iter [30/209], Loss: total=1.43372, reg=16.20563, containing_obj=12.37305, no_obj=5.00578, cls=0.82475
# Epoch [3/10], Iter [40/209], Loss: total=1.46802, reg=16.69775, containing_obj=12.63040, no_obj=4.96225, cls=0.94199
# Epoch [3/10], Iter [50/209], Loss: total=1.46287, reg=16.68426, containing_obj=12.49776, no_obj=4.99824, cls=0.92851
# Epoch [3/10], Iter [60/209], Loss: total=1.50030, reg=17.29820, containing_obj=12.74580, no_obj=4.99056, cls=0.97256
# Epoch [3/10], Iter [70/209], Loss: total=1.49451, reg=17.16775, containing_obj=12.71923, no_obj=5.02158, cls=0.95978
# Epoch [3/10], Iter [80/209], Loss: total=1.49064, reg=17.13122, containing_obj=12.71294, no_obj=4.99489, cls=0.93639
# Epoch [3/10], Iter [90/209], Loss: total=1.51045, reg=17.33503, containing_obj=12.95888, no_obj=4.99967, cls=0.95716
# Epoch [3/10], Iter [100/209], Loss: total=1.49946, reg=17.11189, containing_obj=12.90524, no_obj=5.01524, cls=0.95476
# Epoch [3/10], Iter [110/209], Loss: total=1.49925, reg=17.11376, containing_obj=12.91724, no_obj=5.01140, cls=0.93963
# Epoch [3/10], Iter [120/209], Loss: total=1.49821, reg=17.07889, containing_obj=12.92496, no_obj=5.03844, cls=0.91474
# Epoch [3/10], Iter [130/209], Loss: total=1.48996, reg=17.00121, containing_obj=12.78679, no_obj=5.06203, cls=0.90895
# Epoch [3/10], Iter [140/209], Loss: total=1.49079, reg=17.04468, containing_obj=12.76071, no_obj=5.05419, cls=0.91938
# Epoch [3/10], Iter [150/209], Loss: total=1.48549, reg=16.96208, containing_obj=12.72204, no_obj=5.06767, cls=0.89992
# Epoch [3/10], Iter [160/209], Loss: total=1.48606, reg=16.98322, containing_obj=12.72705, no_obj=5.05300, cls=0.90227
# Epoch [3/10], Iter [170/209], Loss: total=1.48526, reg=16.96620, containing_obj=12.74072, no_obj=5.04880, cls=0.89043
# Epoch [3/10], Iter [180/209], Loss: total=1.47933, reg=16.86078, containing_obj=12.73510, no_obj=5.05147, cls=0.85647
# Epoch [3/10], Iter [190/209], Loss: total=1.47182, reg=16.78733, containing_obj=12.61989, no_obj=5.04924, cls=0.86723
# Epoch [3/10], Iter [200/209], Loss: total=1.46279, reg=16.64696, containing_obj=12.52501, no_obj=5.06466, cls=0.87040
#
#
# Starting epoch 4 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [4/10], Iter [10/209], Loss: total=1.51626, reg=17.92079, containing_obj=12.33576, no_obj=5.41420, cls=0.71957
# Epoch [4/10], Iter [20/209], Loss: total=1.50309, reg=17.34084, containing_obj=12.82900, no_obj=5.24052, cls=0.66386
# Epoch [4/10], Iter [30/209], Loss: total=1.42993, reg=16.34359, containing_obj=12.20799, no_obj=5.22087, cls=0.54580
# Epoch [4/10], Iter [40/209], Loss: total=1.40833, reg=16.19482, containing_obj=11.76396, no_obj=5.24411, cls=0.59695
# Epoch [4/10], Iter [50/209], Loss: total=1.41809, reg=16.29196, containing_obj=11.93223, no_obj=5.20072, cls=0.60925
# Epoch [4/10], Iter [60/209], Loss: total=1.40907, reg=16.11486, containing_obj=11.76847, no_obj=5.25357, cls=0.68083
# Epoch [4/10], Iter [70/209], Loss: total=1.40965, reg=16.02749, containing_obj=11.80091, no_obj=5.24815, cls=0.75509
# Epoch [4/10], Iter [80/209], Loss: total=1.40216, reg=15.86877, containing_obj=11.77608, no_obj=5.22537, cls=0.78152
# Epoch [4/10], Iter [90/209], Loss: total=1.40084, reg=15.87962, containing_obj=11.76910, no_obj=5.21191, cls=0.75947
# Epoch [4/10], Iter [100/209], Loss: total=1.41279, reg=16.01977, containing_obj=11.87776, no_obj=5.18749, cls=0.82187
# Epoch [4/10], Iter [110/209], Loss: total=1.42794, reg=16.15906, containing_obj=12.08803, no_obj=5.16546, cls=0.85799
# Epoch [4/10], Iter [120/209], Loss: total=1.43429, reg=16.23307, containing_obj=12.19685, no_obj=5.14635, cls=0.84663
# Epoch [4/10], Iter [130/209], Loss: total=1.43994, reg=16.31880, containing_obj=12.25191, no_obj=5.15052, cls=0.83731
# Epoch [4/10], Iter [140/209], Loss: total=1.44944, reg=16.42710, containing_obj=12.38202, no_obj=5.15073, cls=0.82661
# Epoch [4/10], Iter [150/209], Loss: total=1.45022, reg=16.41862, containing_obj=12.37507, no_obj=5.15295, cls=0.85862
# Epoch [4/10], Iter [160/209], Loss: total=1.44993, reg=16.42364, containing_obj=12.35659, no_obj=5.16208, cls=0.85603
# Epoch [4/10], Iter [170/209], Loss: total=1.45601, reg=16.48155, containing_obj=12.42625, no_obj=5.15579, cls=0.88068
# Epoch [4/10], Iter [180/209], Loss: total=1.45231, reg=16.48174, containing_obj=12.32872, no_obj=5.16322, cls=0.88171
# Epoch [4/10], Iter [190/209], Loss: total=1.45488, reg=16.45877, containing_obj=12.39637, no_obj=5.16167, cls=0.90021
# Epoch [4/10], Iter [200/209], Loss: total=1.45552, reg=16.48771, containing_obj=12.39719, no_obj=5.16207, cls=0.88560
#
#
# Starting epoch 5 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [5/10], Iter [10/209], Loss: total=1.58519, reg=18.47940, containing_obj=13.60153, no_obj=4.91049, cls=1.05309
# Epoch [5/10], Iter [20/209], Loss: total=1.46178, reg=16.69014, containing_obj=12.51953, no_obj=5.07674, cls=0.79638
# Epoch [5/10], Iter [30/209], Loss: total=1.42914, reg=16.16181, containing_obj=12.23721, no_obj=5.13531, cls=0.76505
# Epoch [5/10], Iter [40/209], Loss: total=1.46731, reg=16.50808, containing_obj=12.79537, no_obj=5.08105, cls=0.83092
# Epoch [5/10], Iter [50/209], Loss: total=1.48394, reg=16.92883, containing_obj=12.67462, no_obj=5.11115, cls=0.90006
# Epoch [5/10], Iter [60/209], Loss: total=1.46241, reg=16.53645, containing_obj=12.58721, no_obj=5.11996, cls=0.85419
# Epoch [5/10], Iter [70/209], Loss: total=1.46281, reg=16.48848, containing_obj=12.56944, no_obj=5.11410, cls=0.93553
# Epoch [5/10], Iter [80/209], Loss: total=1.45318, reg=16.33915, containing_obj=12.44890, no_obj=5.13265, cls=0.95571
# Epoch [5/10], Iter [90/209], Loss: total=1.45310, reg=16.43062, containing_obj=12.33640, no_obj=5.12936, cls=0.97790
# Epoch [5/10], Iter [100/209], Loss: total=1.45456, reg=16.54160, containing_obj=12.30990, no_obj=5.11615, cls=0.94176
# Epoch [5/10], Iter [110/209], Loss: total=1.45263, reg=16.47556, containing_obj=12.29715, no_obj=5.14188, cls=0.94861
# Epoch [5/10], Iter [120/209], Loss: total=1.45667, reg=16.54987, containing_obj=12.32380, no_obj=5.16231, cls=0.92403
# Epoch [5/10], Iter [130/209], Loss: total=1.44753, reg=16.42315, containing_obj=12.21362, no_obj=5.16097, cls=0.94297
# Epoch [5/10], Iter [140/209], Loss: total=1.44939, reg=16.43996, containing_obj=12.24274, no_obj=5.17297, cls=0.92963
# Epoch [5/10], Iter [150/209], Loss: total=1.45247, reg=16.47330, containing_obj=12.25692, no_obj=5.17958, cls=0.94944
# Epoch [5/10], Iter [160/209], Loss: total=1.45812, reg=16.53735, containing_obj=12.33658, no_obj=5.15591, cls=0.96499
# Epoch [5/10], Iter [170/209], Loss: total=1.46137, reg=16.58707, containing_obj=12.40367, no_obj=5.13605, cls=0.94616
# Epoch [5/10], Iter [180/209], Loss: total=1.46060, reg=16.58158, containing_obj=12.39335, no_obj=5.13823, cls=0.94115
# Epoch [5/10], Iter [190/209], Loss: total=1.45510, reg=16.52963, containing_obj=12.31558, no_obj=5.14296, cls=0.93430
# Epoch [5/10], Iter [200/209], Loss: total=1.45811, reg=16.57794, containing_obj=12.33947, no_obj=5.13417, cls=0.94308
#
#
# Starting epoch 6 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [6/10], Iter [10/209], Loss: total=1.51764, reg=17.76952, containing_obj=13.09268, no_obj=4.74295, cls=0.81826
# Epoch [6/10], Iter [20/209], Loss: total=1.44141, reg=16.60462, containing_obj=12.19217, no_obj=4.98891, cls=0.80805
# Epoch [6/10], Iter [30/209], Loss: total=1.48176, reg=17.08430, containing_obj=12.64755, no_obj=5.01230, cls=0.81818
# Epoch [6/10], Iter [40/209], Loss: total=1.47054, reg=16.96367, containing_obj=12.53997, no_obj=4.96802, cls=0.82131
# Epoch [6/10], Iter [50/209], Loss: total=1.45317, reg=16.73052, containing_obj=12.31759, no_obj=5.01042, cls=0.81745
# Epoch [6/10], Iter [60/209], Loss: total=1.44411, reg=16.46481, containing_obj=12.29428, no_obj=5.05016, cls=0.84928
# Epoch [6/10], Iter [70/209], Loss: total=1.43647, reg=16.30524, containing_obj=12.30970, no_obj=5.04759, cls=0.81269
# Epoch [6/10], Iter [80/209], Loss: total=1.44672, reg=16.33998, containing_obj=12.48986, no_obj=5.07435, cls=0.81718
# Epoch [6/10], Iter [90/209], Loss: total=1.45663, reg=16.45815, containing_obj=12.57122, no_obj=5.07966, cls=0.85010
# Epoch [6/10], Iter [100/209], Loss: total=1.44203, reg=16.23971, containing_obj=12.45527, no_obj=5.08175, cls=0.83188
# Epoch [6/10], Iter [110/209], Loss: total=1.42226, reg=15.97983, containing_obj=12.20016, no_obj=5.10928, cls=0.84501
# Epoch [6/10], Iter [120/209], Loss: total=1.42614, reg=15.97390, containing_obj=12.25861, no_obj=5.11798, cls=0.87697
# Epoch [6/10], Iter [130/209], Loss: total=1.42804, reg=16.05230, containing_obj=12.22511, no_obj=5.11395, cls=0.88164
# Epoch [6/10], Iter [140/209], Loss: total=1.43531, reg=16.11449, containing_obj=12.32145, no_obj=5.11361, cls=0.89777
# Epoch [6/10], Iter [150/209], Loss: total=1.43359, reg=16.05699, containing_obj=12.34886, no_obj=5.11492, cls=0.88550
# Epoch [6/10], Iter [160/209], Loss: total=1.43308, reg=16.05834, containing_obj=12.32595, no_obj=5.11717, cls=0.89256
# Epoch [6/10], Iter [170/209], Loss: total=1.43313, reg=16.07625, containing_obj=12.32804, no_obj=5.11324, cls=0.87751
# Epoch [6/10], Iter [180/209], Loss: total=1.43783, reg=16.17653, containing_obj=12.35430, no_obj=5.10715, cls=0.86998
# Epoch [6/10], Iter [190/209], Loss: total=1.44166, reg=16.24214, containing_obj=12.39320, no_obj=5.09382, cls=0.87067
# Epoch [6/10], Iter [200/209], Loss: total=1.44835, reg=16.35264, containing_obj=12.46124, no_obj=5.09372, cls=0.85279
#
#
# Starting epoch 7 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [7/10], Iter [10/209], Loss: total=1.49075, reg=17.30901, containing_obj=12.06218, no_obj=5.35752, cls=1.04917
# Epoch [7/10], Iter [20/209], Loss: total=1.51441, reg=17.57894, containing_obj=12.59549, no_obj=5.32385, cls=0.84763
# Epoch [7/10], Iter [30/209], Loss: total=1.50029, reg=17.09531, containing_obj=12.69464, no_obj=5.24818, cls=0.96892
# Epoch [7/10], Iter [40/209], Loss: total=1.50429, reg=17.15813, containing_obj=12.84921, no_obj=5.19041, cls=0.90516
# Epoch [7/10], Iter [50/209], Loss: total=1.46304, reg=16.60205, containing_obj=12.43880, no_obj=5.21950, cls=0.85263
# Epoch [7/10], Iter [60/209], Loss: total=1.44063, reg=16.28303, containing_obj=12.23455, no_obj=5.20912, cls=0.84840
# Epoch [7/10], Iter [70/209], Loss: total=1.41976, reg=15.99168, containing_obj=11.99238, no_obj=5.23376, cls=0.85650
# Epoch [7/10], Iter [80/209], Loss: total=1.41363, reg=15.81607, containing_obj=12.01901, no_obj=5.26169, cls=0.83033
# Epoch [7/10], Iter [90/209], Loss: total=1.43104, reg=16.03506, containing_obj=12.27343, no_obj=5.21460, cls=0.82188
# Epoch [7/10], Iter [100/209], Loss: total=1.43668, reg=16.13438, containing_obj=12.35414, no_obj=5.17776, cls=0.81408
# Epoch [7/10], Iter [110/209], Loss: total=1.42674, reg=15.96092, containing_obj=12.27642, no_obj=5.18566, cls=0.81877
# Epoch [7/10], Iter [120/209], Loss: total=1.43211, reg=16.10486, containing_obj=12.28003, no_obj=5.17580, cls=0.80995
# Epoch [7/10], Iter [130/209], Loss: total=1.43613, reg=16.09788, containing_obj=12.36337, no_obj=5.18230, cls=0.82347
# Epoch [7/10], Iter [140/209], Loss: total=1.43554, reg=16.14873, containing_obj=12.30036, no_obj=5.16353, cls=0.84032
# Epoch [7/10], Iter [150/209], Loss: total=1.43964, reg=16.22154, containing_obj=12.29956, no_obj=5.16825, cls=0.86201
# Epoch [7/10], Iter [160/209], Loss: total=1.44956, reg=16.43997, containing_obj=12.32994, no_obj=5.15721, cls=0.86236
# Epoch [7/10], Iter [170/209], Loss: total=1.44925, reg=16.40717, containing_obj=12.35057, no_obj=5.15916, cls=0.86512
# Epoch [7/10], Iter [180/209], Loss: total=1.44570, reg=16.34367, containing_obj=12.34638, no_obj=5.14686, cls=0.85983
# Epoch [7/10], Iter [190/209], Loss: total=1.45452, reg=16.44788, containing_obj=12.42877, no_obj=5.14836, cls=0.88339
# Epoch [7/10], Iter [200/209], Loss: total=1.45145, reg=16.42835, containing_obj=12.38151, no_obj=5.15546, cls=0.86953
#
#
# Starting epoch 8 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [8/10], Iter [10/209], Loss: total=1.57612, reg=18.30155, containing_obj=13.43606, no_obj=5.14500, cls=0.94419
# Epoch [8/10], Iter [20/209], Loss: total=1.48645, reg=16.86429, containing_obj=12.90375, no_obj=5.11912, cls=0.78755
# Epoch [8/10], Iter [30/209], Loss: total=1.46684, reg=16.57854, containing_obj=12.54271, no_obj=5.12936, cls=0.95355
# Epoch [8/10], Iter [40/209], Loss: total=1.49052, reg=16.95732, containing_obj=12.78524, no_obj=5.15346, cls=0.87641
# Epoch [8/10], Iter [50/209], Loss: total=1.50189, reg=16.97961, containing_obj=12.99992, no_obj=5.13942, cls=0.92634
# Epoch [8/10], Iter [60/209], Loss: total=1.50041, reg=17.05385, containing_obj=12.93521, no_obj=5.15407, cls=0.86674
# Epoch [8/10], Iter [70/209], Loss: total=1.50075, reg=17.03585, containing_obj=12.90490, no_obj=5.17903, cls=0.89821
# Epoch [8/10], Iter [80/209], Loss: total=1.49169, reg=16.85179, containing_obj=12.86616, no_obj=5.20700, cls=0.87562
# Epoch [8/10], Iter [90/209], Loss: total=1.47431, reg=16.63543, containing_obj=12.67133, no_obj=5.20380, cls=0.87282
# Epoch [8/10], Iter [100/209], Loss: total=1.46540, reg=16.48864, containing_obj=12.56426, no_obj=5.23474, cls=0.88204
# Epoch [8/10], Iter [110/209], Loss: total=1.45666, reg=16.35420, containing_obj=12.42860, no_obj=5.25233, cls=0.92469
# Epoch [8/10], Iter [120/209], Loss: total=1.44735, reg=16.21237, containing_obj=12.39474, no_obj=5.23806, cls=0.89117
# Epoch [8/10], Iter [130/209], Loss: total=1.45837, reg=16.38933, containing_obj=12.50280, no_obj=5.21413, cls=0.89457
# Epoch [8/10], Iter [140/209], Loss: total=1.44738, reg=16.23497, containing_obj=12.42168, no_obj=5.22052, cls=0.85998
# Epoch [8/10], Iter [150/209], Loss: total=1.44283, reg=16.17075, containing_obj=12.36715, no_obj=5.23149, cls=0.85849
# Epoch [8/10], Iter [160/209], Loss: total=1.44023, reg=16.16796, containing_obj=12.30213, no_obj=5.24257, cls=0.85294
# Epoch [8/10], Iter [170/209], Loss: total=1.43908, reg=16.17413, containing_obj=12.28879, no_obj=5.23799, cls=0.83700
# Epoch [8/10], Iter [180/209], Loss: total=1.43919, reg=16.21923, containing_obj=12.26185, no_obj=5.22430, cls=0.83508
# Epoch [8/10], Iter [190/209], Loss: total=1.43948, reg=16.23090, containing_obj=12.26990, no_obj=5.19664, cls=0.85019
# Epoch [8/10], Iter [200/209], Loss: total=1.43727, reg=16.19488, containing_obj=12.24559, no_obj=5.20179, cls=0.85233
#
#
# Starting epoch 9 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [9/10], Iter [10/209], Loss: total=1.39559, reg=16.38580, containing_obj=11.35374, no_obj=5.15876, cls=0.59597
# Epoch [9/10], Iter [20/209], Loss: total=1.41344, reg=16.24151, containing_obj=11.65183, no_obj=5.16748, cls=0.86165
# Epoch [9/10], Iter [30/209], Loss: total=1.39906, reg=15.78102, containing_obj=11.67304, no_obj=5.14279, cls=0.98056
# Epoch [9/10], Iter [40/209], Loss: total=1.36683, reg=15.23611, containing_obj=11.49079, no_obj=5.18093, cls=0.89617
# Epoch [9/10], Iter [50/209], Loss: total=1.38224, reg=15.31793, containing_obj=11.83298, no_obj=5.15622, cls=0.86669
# Epoch [9/10], Iter [60/209], Loss: total=1.39193, reg=15.51931, containing_obj=11.85995, no_obj=5.14243, cls=0.88457
# Epoch [9/10], Iter [70/209], Loss: total=1.39716, reg=15.51408, containing_obj=11.91712, no_obj=5.20000, cls=0.90061
# Epoch [9/10], Iter [80/209], Loss: total=1.39308, reg=15.48529, containing_obj=11.83377, no_obj=5.21418, cls=0.90073
# Epoch [9/10], Iter [90/209], Loss: total=1.42059, reg=15.80330, containing_obj=12.20111, no_obj=5.17637, cls=0.91345
# Epoch [9/10], Iter [100/209], Loss: total=1.41581, reg=15.89619, containing_obj=12.01073, no_obj=5.16843, cls=0.90417
# Epoch [9/10], Iter [110/209], Loss: total=1.42019, reg=15.92095, containing_obj=12.11589, no_obj=5.14543, cls=0.90220
# Epoch [9/10], Iter [120/209], Loss: total=1.42310, reg=16.00039, containing_obj=12.09579, no_obj=5.15317, cls=0.90509
# Epoch [9/10], Iter [130/209], Loss: total=1.42489, reg=15.99861, containing_obj=12.14687, no_obj=5.16398, cls=0.88786
# Epoch [9/10], Iter [140/209], Loss: total=1.42338, reg=15.99870, containing_obj=12.08363, no_obj=5.20917, cls=0.86959
# Epoch [9/10], Iter [150/209], Loss: total=1.41908, reg=15.88732, containing_obj=12.10182, no_obj=5.20351, cls=0.86530
# Epoch [9/10], Iter [160/209], Loss: total=1.41957, reg=15.89711, containing_obj=12.11140, no_obj=5.19416, cls=0.86699
# Epoch [9/10], Iter [170/209], Loss: total=1.42260, reg=16.01229, containing_obj=12.08439, no_obj=5.19260, cls=0.85310
# Epoch [9/10], Iter [180/209], Loss: total=1.42209, reg=16.00879, containing_obj=12.06984, no_obj=5.18767, cls=0.86382
# Epoch [9/10], Iter [190/209], Loss: total=1.42526, reg=16.06237, containing_obj=12.10317, no_obj=5.19489, cls=0.84569
# Epoch [9/10], Iter [200/209], Loss: total=1.42659, reg=16.05481, containing_obj=12.13527, no_obj=5.19293, cls=0.85516
#
#
# Starting epoch 10 / 10
# Learning Rate for this epoch: 0.0001
# Epoch [10/10], Iter [10/209], Loss: total=1.45964, reg=16.44597, containing_obj=12.51143, no_obj=5.34854, cls=0.72551
# Epoch [10/10], Iter [20/209], Loss: total=1.34854, reg=14.90875, containing_obj=11.45198, no_obj=5.31686, cls=0.68731
# Epoch [10/10], Iter [30/209], Loss: total=1.36888, reg=15.29643, containing_obj=11.63058, no_obj=5.20423, cls=0.72181
# Epoch [10/10], Iter [40/209], Loss: total=1.38321, reg=15.55704, containing_obj=11.54331, no_obj=5.21773, cls=0.87890
# Epoch [10/10], Iter [50/209], Loss: total=1.36953, reg=15.48825, containing_obj=11.36972, no_obj=5.18741, cls=0.82343
# Epoch [10/10], Iter [60/209], Loss: total=1.38176, reg=15.63266, containing_obj=11.49180, no_obj=5.17982, cls=0.85790
# Epoch [10/10], Iter [70/209], Loss: total=1.39584, reg=15.84308, containing_obj=11.63256, no_obj=5.15348, cls=0.87106
# Epoch [10/10], Iter [80/209], Loss: total=1.41979, reg=16.10509, containing_obj=11.98172, no_obj=5.11473, cls=0.87351
# Epoch [10/10], Iter [90/209], Loss: total=1.41903, reg=16.03602, containing_obj=11.99893, no_obj=5.13334, cls=0.88842
# Epoch [10/10], Iter [100/209], Loss: total=1.42537, reg=16.18978, containing_obj=11.97898, no_obj=5.15918, cls=0.88082
# Epoch [10/10], Iter [110/209], Loss: total=1.43197, reg=16.29744, containing_obj=11.99937, no_obj=5.17315, cls=0.89731
# Epoch [10/10], Iter [120/209], Loss: total=1.42313, reg=16.17511, containing_obj=11.93741, no_obj=5.17559, cls=0.86710
# Epoch [10/10], Iter [130/209], Loss: total=1.43120, reg=16.33196, containing_obj=11.96350, no_obj=5.17213, cls=0.88132
# Epoch [10/10], Iter [140/209], Loss: total=1.43357, reg=16.33424, containing_obj=12.00345, no_obj=5.16984, cls=0.89815
# Epoch [10/10], Iter [150/209], Loss: total=1.42808, reg=16.27225, containing_obj=11.94143, no_obj=5.16965, cls=0.89059
# Epoch [10/10], Iter [160/209], Loss: total=1.43812, reg=16.36596, containing_obj=12.07924, no_obj=5.17197, cls=0.89764
# Epoch [10/10], Iter [170/209], Loss: total=1.44334, reg=16.42506, containing_obj=12.12337, no_obj=5.17521, cls=0.91646
# Epoch [10/10], Iter [180/209], Loss: total=1.43762, reg=16.35018, containing_obj=12.05982, no_obj=5.18101, cls=0.91189
# Epoch [10/10], Iter [190/209], Loss: total=1.44584, reg=16.49066, containing_obj=12.13561, no_obj=5.17699, cls=0.89677
# Epoch [10/10], Iter [200/209], Loss: total=1.44271, reg=16.45450, containing_obj=12.12424, no_obj=5.17343, cls=0.87288

# %% [markdown]
# # View example predictions

# %%
runtime.unassign()

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
# Out:
# predicting...

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [03:18<00:00, 24.92it/s]
# ---class aeroplane ap 0.4749644371396101---
# ---class bicycle ap 0.6234741555579624---
# ---class bird ap 0.46447608902802---
# ---class boat ap 0.289732889544075---
# ---class bottle ap 0.2037296685529139---
# ---class bus ap 0.5696976952693074---
# ---class car ap 0.6509817445926775---
# ---class cat ap 0.6843513583171698---
# ---class chair ap 0.2840110839630033---
# ---class cow ap 0.5429865065015649---
# ---class diningtable ap 0.3306753418492885---
# ---class dog ap 0.6650100989641728---
# ---class horse ap 0.6965241473036494---
# ---class motorbike ap 0.5665915311318523---
# ---class person ap 0.5245406968819964---
# ---class pottedplant ap 0.16929207418332998---
# ---class sheep ap 0.4623862087151975---
# ---class sofa ap 0.46929313674917184---
# ---class train ap 0.6046380081811256---
# ---class tvmonitor ap 0.4951696439240413---
# ---map 0.4886263258175066---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['./checkpoints/detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40]]+['./checkpoints/detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)

# %%
output_submission_csv('my_new_solution.csv', test_aps)

# %%
runtime.unassign()
